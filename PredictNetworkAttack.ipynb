# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham-dalmia/Cpp-Patterns-Basic/blob/main/PredictNetworkAttack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
df= pd.read_csv('train.csv')
#X = dataset.iloc[:,:-1].values
#Y = dataset.iloc[:,-1].values
df
# Out:
#           Id  duration  ... dst_host_srv_rerror_rate type_of_attack
# 0          1         0  ...                     1.00         satan.
# 1          2         0  ...                     0.01          back.
# 2          3         0  ...                     1.00         satan.
# 3          4         0  ...                     0.00       ipsweep.
# 4          5         0  ...                     1.00         satan.
# ...      ...       ...  ...                      ...            ...
# 12984  12985         0  ...                     1.00         satan.
# 12985  12986         0  ...                     1.00         satan.
# 12986  12987         0  ...                     0.00       ipsweep.
# 12987  12988         0  ...                     1.00       ipsweep.
# 12988  12989         0  ...                     1.00     portsweep.
#
# [12989 rows x 43 columns]

# %%
df.groupby(['Id']).mean().sum()
# Out:
# duration                           2040.00
# src_bytes                      76182668.00
# dst_bytes                      14257117.00
# land                                  0.00
# wrong_fragment                        0.00
# urgent                                0.00
# hot                                2764.00
# num_failed_logins                     0.00
# logged_in                          1996.00
# num_compromised                    1363.00
# root_shell                            0.00
# su_attempted                          0.00
# num_root                              2.00
# num_file_creations                    0.00
# num_shells                            1.00
# num_access_files                      1.00
# num_outbound_cmds                     0.00
# is_host_login                         0.00
# is_guest_login                        0.00
# count                           1699812.00
# srv_count                        141339.00
# serror_rate                         334.24
# ...

# %%
df.groupby(['type_of_attack']).mean()
# Out:
#                          Id  ...  dst_host_srv_rerror_rate
# type_of_attack               ...
# back.           6270.305000  ...                  0.037900
# ipsweep.        6510.997555  ...                  0.113860
# normal.         6677.573975  ...                  0.000000
# portsweep.      6448.886943  ...                  0.916153
# satan.          6554.082188  ...                  0.863207
#
# [5 rows x 39 columns]

# %%
df.groupby(['protocol_type']).mean()
# Out:
#                         Id  ...  dst_host_srv_rerror_rate
# protocol_type               ...
# icmp           6524.744695  ...                  0.000000
# tcp            6483.352583  ...                  0.707069
# udp            6329.654412  ...                  0.000000
#
# [3 rows x 39 columns]

# %%
df.groupby(['service']).mean()
# Out:
#                      Id  ...  dst_host_srv_rerror_rate
# service                  ...
# IRC        10391.000000  ...                  1.000000
# X11         5852.000000  ...                  1.000000
# Z39_50      6996.000000  ...                  1.000000
# auth        5385.000000  ...                  0.400000
# bgp         6915.000000  ...                  1.000000
# ...                 ...  ...                       ...
# time        7173.230769  ...                  0.269231
# uucp        6028.666667  ...                  0.666667
# uucp_path  10957.000000  ...                  1.000000
# vmnet      12314.000000  ...                  1.000000
# whois       7274.307692  ...                  0.923077
#
# [61 rows x 39 columns]

# %%
df.groupby(['flag']).mean()
# Out:
#                  Id  duration  ...  dst_host_rerror_rate  dst_host_srv_rerror_rate
# flag                           ...
# OTH     6019.000000  0.000000  ...              0.994000                  0.000000
# REJ     6516.945445  0.000000  ...              0.910334                  0.996766
# RSTO    6119.194444  2.805556  ...              0.875278                  0.785278
# RSTOS0  7465.671053  1.000000  ...              0.248947                  0.525789
# RSTR    6404.385388  0.825990  ...              0.871227                  0.975165
# S0      6815.627760  0.000000  ...              0.618265                  0.010599
# S1      7762.500000  0.000000  ...              0.035000                  0.035000
# S2      5051.750000  0.000000  ...              0.065000                  0.037500
# SF      6483.756101  0.055162  ...              0.025502                  0.007860
#
# [9 rows x 39 columns]

# %%
#train_dataset=pd.DataFrame(X)
#print(train_dataset)

# %%
#train_dataset.isnull().sum()

# %%
#train_dataset.info()

# %%
test_dataset=pd.read_csv('test.csv')
test_dataset
# Out:
#         Id  duration  ... dst_host_rerror_rate dst_host_srv_rerror_rate
# 0        1         0  ...                 0.00                     0.00
# 1        2         0  ...                 0.00                     0.00
# 2        3         0  ...                 0.00                     0.00
# 3        4         0  ...                 0.00                     0.00
# 4        5         0  ...                 0.00                     0.00
# ...    ...       ...  ...                  ...                      ...
# 5562  5563         0  ...                 0.05                     0.05
# 5563  5564         0  ...                 0.00                     0.00
# 5564  5565         0  ...                 0.00                     0.00
# 5565  5566         0  ...                 0.05                     0.05
# 5566  5567         0  ...                 0.00                     0.00
#
# [5567 rows x 42 columns]

# %%
test_dataset.isnull().sum()
# Out:
# Id                             0
# duration                       0
# protocol_type                  0
# service                        0
# flag                           1
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# ...

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5567 entries, 0 to 5566
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           5567 non-null   int64
#  1   duration                     5567 non-null   int64
#  2   protocol_type                5567 non-null   object
#  3   service                      5567 non-null   object
#  4   flag                         5566 non-null   object
#  5   src_bytes                    5567 non-null   int64
#  6   dst_bytes                    5567 non-null   int64
#  7   land                         5567 non-null   int64
#  8   wrong_fragment               5567 non-null   int64
#  9   urgent                       5567 non-null   int64
#  10  hot                          5567 non-null   int64
#  11  num_failed_logins            5567 non-null   int64
#  12  logged_in                    5567 non-null   int64
# ...

# %%
df.type_of_attack[df.type_of_attack == 'back.']=1
df.type_of_attack[df.type_of_attack == 'ipsweep.']=2
df.type_of_attack[df.type_of_attack == 'normal.']=3
df.type_of_attack[df.type_of_attack == 'portsweep.']=4
df.type_of_attack[df.type_of_attack == 'satan.']=5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
new=df.join([pd.get_dummies(df.protocol_type,prefix="protocol_type")])
new=df.join([pd.get_dummies(df.service,prefix="service")])
new=df.join([pd.get_dummies(df.flag,prefix="flag")])
neww=new.drop(['protocol_type','service','flag'],axis=1)
neww
# Out:
#           Id  duration  src_bytes  ...  flag_S1  flag_S2  flag_SF
# 0          1         0          0  ...        0        0        0
# 1          2         0      54540  ...        0        0        1
# 2          3         0          0  ...        0        0        0
# 3          4         0          8  ...        0        0        1
# 4          5         0          0  ...        0        0        0
# ...      ...       ...        ...  ...      ...      ...      ...
# 12984  12985         0          0  ...        0        0        0
# 12985  12986         0          0  ...        0        0        0
# 12986  12987         0          8  ...        0        0        1
# 12987  12988         0          0  ...        0        0        0
# 12988  12989         0          0  ...        0        0        0
#
# [12989 rows x 49 columns]

# %%
new_t=test_dataset.join([pd.get_dummies(df.protocol_type,prefix="protocol_type")])
new_t=test_dataset.join([pd.get_dummies(df.service,prefix="service")])
new_t=test_dataset.join([pd.get_dummies(df.flag,prefix="flag")])
new_td=new_t.drop(['protocol_type','service','flag'],axis=1)
new_td
# Out:
#           Id  duration  src_bytes  ...  flag_S1  flag_S2  flag_SF
# 0        1.0       0.0        8.0  ...        0        0        0
# 1        2.0       0.0        8.0  ...        0        0        1
# 2        3.0       0.0        8.0  ...        0        0        0
# 3        4.0       0.0        8.0  ...        0        0        1
# 4        5.0       0.0        8.0  ...        0        0        0
# ...      ...       ...        ...  ...      ...      ...      ...
# 5562  5563.0       0.0    54540.0  ...        0        0        1
# 5563  5564.0       0.0        8.0  ...        0        0        1
# 5564  5565.0       0.0        8.0  ...        0        0        1
# 5565  5566.0       0.0    54540.0  ...        0        0        1
# 5566  5567.0       0.0        8.0  ...        0        0        0
#
# [5567 rows x 48 columns]

# %%
neww.shape
# Out:
# (12989, 49)

# %%
new_td.shape
# Out:
# (5567, 48)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(neww.drop(['type_of_attack'],axis=1), neww.type_of_attack, test_size=0.2)

# %%
y_train=y_train.astype('int')
y_test=y_test.astype('int')

# %%
#final_df=pd.concat([new_td,neww],axis=0)
#final_df.shape

# %%
#final_df=final_df.loc[:,~final_df.columns.duplicated()]

# %%
#final_df.shape

# %%
#df_Train=final_df.iloc[:12989,:]
#df_Test=final_df.iloc[5567:,:]

# %%
#df_Test.drop(['type_of_attack'],axis=1,inplace=True)

# %%
#df_Test.shape

# %%
#X_train=df_Train.drop(['type_of_attack'],axis=1)
#y_train=df_Train['type_of_attack']

# %%
#import xgboost
#classifier=xgboost.XGBRegressor()
#classifier.fit(X_train,y_train)

# %%
#y_pred=classifier.predict(df_Test)

# %%
#y_pred.shape

# %%
#Pred=pd.DataFrame(y_pred)

# %%
#Pred.value_counts()

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.predict(X_test)
# Out:
# array([2, 2, 4, ..., 5, 2, 5])

# %%
model.score(X_test,y_test)
# Out:
# 0.9507313317936874

# %%
y_pred=model.predict(new_td)

# %%
pred=pd.DataFrame(y_pred)

# %%
pred.columns=['type_of_attack']

# %%
pred
# Out:
#       type_of_attack
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 5562               1
# 5563               2
# 5564               2
# 5565               1
# 5566               2
#
# [5567 rows x 1 columns]

# %%
pred.type_of_attack[pred.type_of_attack == 1]='back.'
pred.type_of_attack[pred.type_of_attack == 2]='ipsweep.'
pred.type_of_attack[pred.type_of_attack == 3]='normal.'
pred.type_of_attack[pred.type_of_attack == 4]='portsweep.'
pred.type_of_attack[pred.type_of_attack == 5]='satan.'

# %%
pred.value_counts()
# Out:
# type_of_attack
# ipsweep.          2166
# satan.            1559
# portsweep.         994
# back.              604
# normal.            244
# dtype: int64

# %%
sub_df=pd.read_csv('sample_solution.csv')

# %%
datasetss=pd.concat([sub_df['Id'],pred],axis=1)
datasetss.columns=['Id','type_of_attack']
#datasetss=datasets.set_index('Id')
datasetss.to_csv('sample_solution.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-ad8899c77f00> in <module>()
# ...

# %%
datasets.to_csv('final_solution.csv',index=False)
